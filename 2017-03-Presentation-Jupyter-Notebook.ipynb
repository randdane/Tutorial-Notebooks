# %% [markdown]
# # Jupyter Notebook
#
# * Presentation

# %%
# %%html
# <style>
#   table {margin-left: 0;}
# </style>
# Out:
# <style>
#   table {margin-left: 0;}
# </style>

# %% [markdown]
# ## Basics
#
# ### What is it?
#
# * HTML / JavaScript with a kernal (Python, R, Julia, C#, etc.)
#
# #### Modes:
#
# * Command
# * Edit
#
# ### Shortcuts
#
# #### Navigation
#
# |Key(s)|Action|
# |:-:|:---|
# | H | show shortcut menu |
# | A | add cell *above*|
# | B | add cell *below* |
# | M | markdown cell |
# | Y | code cell |
# | DD | delete cell |
# | Shift + Enter | run cell on move to next |
# | Ctrl + Enter | run cell on remain |
# | Alt + Enter | run cell and move to newly created cell |
#
# #### Editing
#
# |Key(s)|Action|
# |:-:|:---|
# | Enter | go into insert mode |
# | Escape | exit insert mode |
# | Tab | code completion |
# | Shift + Tab | tooltips (3 versions) |
# | Ctrl + S | save |
#
#
# ### Markdown:
#
# * Headings (#)
#
# * Lists (*)
#
# * Blockquote
# > This is an example
#
# * Horizontal Rule (---)
#
# * Embedded code (three backticks) ```* this is inline code```
#
# ```python
# def my_function():
#     """My syntax is highlighted for the Python language."""
#     pass
# ```
#
# * LaTeX   $e^{i\pi} + 1 = 0$
# * Linking
#     *External links: ```[name](https://some_website.com)```
#     *Internal links: ```[name](#the_last_cell)```
#
# ---
#
# * http://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Working%20With%20Markdown%20Cells.html
# * http://sebastianraschka.com/Articles/2014_ipython_internal_links.html
# * http://www.datadependence.com/2017/02/speed-up-jupyter-notebook-workflow/
#
# ### Raw:

# %% [raw]
# this is a raw cell

# %% [markdown]
# ### Code:

# %%
some_global_variable = 6

def main(my_var=None):
    """Just for show."""
    if my_var is None:
        my_var = 1
    else: my_var += 1
        
    print('My variable is confused with ' + str(some_global_variable))
    
    return 'My returned variable is ' + str(my_var)

# %%
main(1)
# Out:
# My variable is confused with 6
# 'My returned variable is 2'

# %%
some_global_variable = 100

# %%
main(5)
# Out:
# My variable is confused with 100
# 'My returned variable is 6'

# %%
main(5)
# Out:
# My variable is confused with 6
# 'My returned variable is 6'

# %% [markdown]
# ### Magic
#
# * ```%``` or ```%%```
# * debug, time, timeit, run, and more...

# %%
# %time [x**x for x in range(150)]
# Out:
# Wall time: 0 ns
# [1,
#  1,
#  4,
#  27,
#  256,
#  3125,
#  46656,
#  823543,
#  16777216,
#  387420489,
#  10000000000,
#  285311670611,
#  8916100448256,
#  302875106592253,
#  11112006825558016,
#  437893890380859375,
#  18446744073709551616,
#  827240261886336764177,
#  39346408075296537575424,
#  1978419655660313589123979,
#  104857600000000000000000000,
#  5842587018385982521381124421,
#  341427877364219557396646723584,
#  20880467999847912034355032910567,
#  1333735776850284124449081472843776,
#  88817841970012523233890533447265625,
#  6156119580207157310796674288400203776,
#  443426488243037769948249630619149892803,
#  33145523113253374862572728253364605812736,
#  2567686153161211134561828214731016126483469,
#  205891132094649000000000000000000000000000000,
#  17069174130723235958610643029059314756044734431,
#  1461501637330902918203684832716283019655932542976,
#  129110040087761027839616029934664535539337183380513,
#  11756638905368616011414050501310355554617941909569536,
# ...

# %%
# %matplotlib inline
# not "pylab inline"

# %% [markdown]
# ### Bash

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 6A27-6402
#
#  Directory of C:\Users\randall.white\Notebooks\DFW_Pythoneers
#
# 02/20/2017  12:41 PM    <DIR>          .
# 02/20/2017  12:41 PM    <DIR>          ..
# 02/15/2017  08:21 AM    <DIR>          .ipynb_checkpoints
# 02/15/2017  08:21 AM             5,677 2017-02-15-TUTORIAL-Lexical-Closing.ipynb
# 02/20/2017  12:41 PM            31,411 2017-03-Presentation-Jupyter-Notebook.ipynb
#                2 File(s)         37,088 bytes
#                3 Dir(s)  173,638,197,248 bytes free

# %% [markdown]
# ### HTML

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))
# Out:
# <style>.container { width:75% !important; }</style>

# %% [markdown]
# #### Embed YouTube videos.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('HW29067qVWk')

# %% [raw]
# The cell below this contains "<a id='another_cell'></a>" which becomes invisible when rendered in Markdown.

# %% [markdown]
# <a id='the_last_cell'></a>
